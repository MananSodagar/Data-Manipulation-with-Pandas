# %% [markdown]
# # Tyding Messy Datasets  data-refrence  PyCon 2018

# %%
import pandas as pd

# %%
df=pd.read_csv("../data/pew.csv")

# %% [markdown]
# # Problem 1: Column Headers are values not Variable names.

# %%
df
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
pd.melt(df,id_vars='religion')
# Out:
#                   religion            variable  value
# 0                 Agnostic               <$10k     27
# 1                  Atheist               <$10k     12
# 2                 Buddhist               <$10k     27
# 3                 Catholic               <$10k    418
# 4       Don’t know/refused               <$10k     15
# ..                     ...                 ...    ...
# 175               Orthodox  Don't know/refused     73
# 176        Other Christian  Don't know/refused     18
# 177           Other Faiths  Don't know/refused     71
# 178  Other World Religions  Don't know/refused      8
# 179           Unaffiliated  Don't know/refused    597
#
# [180 rows x 3 columns]

# %%
pd.melt(df,id_vars='religion',value_name="count",var_name="income")
# Out:
#                   religion              income  count
# 0                 Agnostic               <$10k     27
# 1                  Atheist               <$10k     12
# 2                 Buddhist               <$10k     27
# 3                 Catholic               <$10k    418
# 4       Don’t know/refused               <$10k     15
# ..                     ...                 ...    ...
# 175               Orthodox  Don't know/refused     73
# 176        Other Christian  Don't know/refused     18
# 177           Other Faiths  Don't know/refused     71
# 178  Other World Religions  Don't know/refused      8
# 179           Unaffiliated  Don't know/refused    597
#
# [180 rows x 3 columns]

# %%
billboard=pd.read_csv("../data/billboard.csv")

# %%
billboard
# Out:
#      year            artist                    track  time date.entered  wk1  \
# 0    2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26   87
# 1    2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02   91
# 2    2000      3 Doors Down               Kryptonite  3:53   2000-04-08   81
# 3    2000      3 Doors Down                    Loser  4:24   2000-10-21   76
# 4    2000          504 Boyz            Wobble Wobble  3:35   2000-04-15   57
# ..    ...               ...                      ...   ...          ...  ...
# 312  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29   86
# 313  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01   85
# 314  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18   95
# 315  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02   99
# 316  2000   matchbox twenty                     Bent  4:12   2000-04-29   60
#
# ...

# %%
billboard_melt=pd.melt(billboard,id_vars=['year','artist','track','time','date.entered'],var_name="week",value_name="ratings")

# %%
billboard.shape
# Out:
# (317, 81)

# %%
billboard_melt.shape
# Out:
# (24092, 7)

# %% [markdown]
# # Problem 2: Multiple Variables are stored in One column

# %%
ebola=pd.read_csv("../data/country_timeseries.csv")

# %%
ebola.head()
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           NaN         8157.0                NaN
# 4  12/31/2014  284        2730.0         8115.0             9633.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# 1            NaN            NaN                 NaN          NaN         NaN
# 2            NaN            NaN                 NaN          NaN         NaN
# 3            NaN            NaN                 NaN          NaN         NaN
# 4            NaN            NaN                 NaN          NaN         NaN
#
#    Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# ...

# %%
ebola_long=pd.melt(ebola,id_vars=["Date","Day"])

# %%
ebola_long.head()
# Out:
#          Date  Day      variable   value
# 0    1/5/2015  289  Cases_Guinea  2776.0
# 1    1/4/2015  288  Cases_Guinea  2775.0
# 2    1/3/2015  287  Cases_Guinea  2769.0
# 3    1/2/2015  286  Cases_Guinea     NaN
# 4  12/31/2014  284  Cases_Guinea  2730.0

# %%
"Cases_Guinea".split("_")[1]
# Out:
# 'Guinea'

# %%
variable_split=ebola_long['variable'].str.split("_")

# %%
variable_split.head()
# Out:
# 0    [Cases, Guinea]
# 1    [Cases, Guinea]
# 2    [Cases, Guinea]
# 3    [Cases, Guinea]
# 4    [Cases, Guinea]
# Name: variable, dtype: object

# %%
variable_split[0]
# Out:
# ['Cases', 'Guinea']

# %%
type(variable_split[0][0])
# Out:
# str

# %%
variable_split.str.get(1)
# Out:
# 0       Guinea
# 1       Guinea
# 2       Guinea
# 3       Guinea
# 4       Guinea
#          ...
# 1947      Mali
# 1948      Mali
# 1949      Mali
# 1950      Mali
# 1951      Mali
# Name: variable, Length: 1952, dtype: object

# %%
ebola_long["stats"]=variable_split.str.get(0)
ebola_long["country"]=variable_split.str.get(1)

# %%
ebola_long.head()
# Out:
#          Date  Day      variable   value  stats country
# 0    1/5/2015  289  Cases_Guinea  2776.0  Cases  Guinea
# 1    1/4/2015  288  Cases_Guinea  2775.0  Cases  Guinea
# 2    1/3/2015  287  Cases_Guinea  2769.0  Cases  Guinea
# 3    1/2/2015  286  Cases_Guinea     NaN  Cases  Guinea
# 4  12/31/2014  284  Cases_Guinea  2730.0  Cases  Guinea

# %%
# another way
ebola_long[["stats_e","country_e"]]=ebola_long["variable"].str.split("_", expand=True)

# %%
ebola_long.head()
# Out:
#          Date  Day      variable   value  stats country stats_e country_e
# 0    1/5/2015  289  Cases_Guinea  2776.0  Cases  Guinea   Cases    Guinea
# 1    1/4/2015  288  Cases_Guinea  2775.0  Cases  Guinea   Cases    Guinea
# 2    1/3/2015  287  Cases_Guinea  2769.0  Cases  Guinea   Cases    Guinea
# 3    1/2/2015  286  Cases_Guinea     NaN  Cases  Guinea   Cases    Guinea
# 4  12/31/2014  284  Cases_Guinea  2730.0  Cases  Guinea   Cases    Guinea

# %% [markdown]
# # Problem 3: Variables are stored in both columns and rows

# %%
weather= pd.read_csv("../data/weather.csv")

# %%
weather.head()
# Out:
#         id  year  month element  d1    d2    d3  d4    d5  d6  ...  d22   d23  \
# 0  MX17004  2010      1    tmax NaN   NaN   NaN NaN   NaN NaN  ...  NaN   NaN
# 1  MX17004  2010      1    tmin NaN   NaN   NaN NaN   NaN NaN  ...  NaN   NaN
# 2  MX17004  2010      2    tmax NaN  27.3  24.1 NaN   NaN NaN  ...  NaN  29.9
# 3  MX17004  2010      2    tmin NaN  14.4  14.4 NaN   NaN NaN  ...  NaN  10.7
# 4  MX17004  2010      3    tmax NaN   NaN   NaN NaN  32.1 NaN  ...  NaN   NaN
#
#    d24  d25  d26  d27  d28  d29   d30  d31
# 0  NaN  NaN  NaN  NaN  NaN  NaN  27.8  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  14.5  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
#
# [5 rows x 35 columns]

# %%
weather_melt=pd.melt(weather,id_vars=['id','year','month','element'],var_name="day",value_name='temprature')

# %%
weather_melt.head()
# Out:
#         id  year  month element day  temprature
# 0  MX17004  2010      1    tmax  d1         NaN
# 1  MX17004  2010      1    tmin  d1         NaN
# 2  MX17004  2010      2    tmax  d1         NaN
# 3  MX17004  2010      2    tmin  d1         NaN
# 4  MX17004  2010      3    tmax  d1         NaN

# %%
weather_tidy_p=weather_melt.pivot(index=['id','year','month','day'],columns='element',values='temprature')

# %%
weather_tidy_p.reset_index()
# Out:
# element       id  year  month  day  tmax  tmin
# 0        MX17004  2010      1   d1   NaN   NaN
# 1        MX17004  2010      1  d10   NaN   NaN
# 2        MX17004  2010      1  d11   NaN   NaN
# 3        MX17004  2010      1  d12   NaN   NaN
# 4        MX17004  2010      1  d13   NaN   NaN
# ..           ...   ...    ...  ...   ...   ...
# 336      MX17004  2010     12   d5   NaN   NaN
# 337      MX17004  2010     12   d6  27.8  10.5
# 338      MX17004  2010     12   d7   NaN   NaN
# 339      MX17004  2010     12   d8   NaN   NaN
# 340      MX17004  2010     12   d9   NaN   NaN
#
# [341 rows x 6 columns]

# %%
weather_tidy_pt=weather_melt.pivot_table(index=['id','year','month','day'],columns='element',values='temprature')

# %%
weather_tidy_pt.reset_index()
# Out:
# element       id  year  month  day  tmax  tmin
# 0        MX17004  2010      1  d30  27.8  14.5
# 1        MX17004  2010      2  d11  29.7  13.4
# 2        MX17004  2010      2   d2  27.3  14.4
# 3        MX17004  2010      2  d23  29.9  10.7
# 4        MX17004  2010      2   d3  24.1  14.4
# 5        MX17004  2010      3  d10  34.5  16.8
# 6        MX17004  2010      3  d16  31.1  17.6
# 7        MX17004  2010      3   d5  32.1  14.2
# 8        MX17004  2010      4  d27  36.3  16.7
# 9        MX17004  2010      5  d27  33.2  18.2
# 10       MX17004  2010      6  d17  28.0  17.5
# 11       MX17004  2010      6  d29  30.1  18.0
# 12       MX17004  2010      7   d3  28.6  17.5
# 13       MX17004  2010      7  d14  29.9  16.5
# 14       MX17004  2010      8  d23  26.4  15.0
# 15       MX17004  2010      8   d5  29.6  15.8
# 16       MX17004  2010      8  d29  28.0  15.3
# 17       MX17004  2010      8  d13  29.8  16.5
# 18       MX17004  2010      8  d25  29.7  15.6
# ...

# %%
del(weather_tidy)

# %% [markdown]
# # Problem 4: Multiple types of observational units are stored in the same table( normalization problem)
#
# # Problem 5: A single observational unit stored in multiple table(viceversa)

# %%
billboard= pd.read_csv("../data/billboard.csv")

# %%
billboard.head()
# Out:
#    year        artist                    track  time date.entered  wk1   wk2  \
# 0  2000         2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26   87  82.0
# 1  2000       2Ge+her  The Hardest Part Of ...  3:15   2000-09-02   91  87.0
# 2  2000  3 Doors Down               Kryptonite  3:53   2000-04-08   81  70.0
# 3  2000  3 Doors Down                    Loser  4:24   2000-10-21   76  76.0
# 4  2000      504 Boyz            Wobble Wobble  3:35   2000-04-15   57  34.0
#
#     wk3   wk4   wk5  ...  wk67  wk68  wk69  wk70  wk71  wk72  wk73  wk74  \
# 0  72.0  77.0  87.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  92.0   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  68.0  67.0  66.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  72.0  69.0  67.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  25.0  17.0  17.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    wk75  wk76
# 0   NaN   NaN
# 1   NaN   NaN
# 2   NaN   NaN
# ...

# %%
billboard_melt.shape
# Out:
# (24092, 7)

# %%
billboard_song_info=billboard_melt.loc[:,"year":"date.entered"]

# %%
billboard_song_info
# Out:
#        year            artist                    track  time date.entered
# 0      2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26
# 1      2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02
# 2      2000      3 Doors Down               Kryptonite  3:53   2000-04-08
# 3      2000      3 Doors Down                    Loser  4:24   2000-10-21
# 4      2000          504 Boyz            Wobble Wobble  3:35   2000-04-15
# ...     ...               ...                      ...   ...          ...
# 24087  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29
# 24088  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01
# 24089  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18
# 24090  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02
# 24091  2000   matchbox twenty                     Bent  4:12   2000-04-29
#
# [24092 rows x 5 columns]

# %%
billboard_song_info.drop_duplicates()
# Out:
#      year            artist                    track  time date.entered
# 0    2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26
# 1    2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02
# 2    2000      3 Doors Down               Kryptonite  3:53   2000-04-08
# 3    2000      3 Doors Down                    Loser  4:24   2000-10-21
# 4    2000          504 Boyz            Wobble Wobble  3:35   2000-04-15
# ..    ...               ...                      ...   ...          ...
# 312  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29
# 313  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01
# 314  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18
# 315  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02
# 316  2000   matchbox twenty                     Bent  4:12   2000-04-29
#
# [317 rows x 5 columns]

# %%
billboard_song_info=billboard_song_info.drop_duplicates()

# %%
billboard_song_info.drop("date.entered", axis=1, inplace=True)
# Out:
# C:\Program Files\Python39\lib\site-packages\pandas\core\frame.py:4305: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
billboard_song_info["id"]=range(len(billboard_song_info))
# Out:
# <ipython-input-78-048bac90f5cb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   billboard_song_info["id"]=range(len(billboard_song_info))

# %%
billboard_song_info
# Out:
#      year            artist                    track  time   id
# 0    2000             2 Pac  Baby Don't Cry (Keep...  4:22    0
# 1    2000           2Ge+her  The Hardest Part Of ...  3:15    1
# 2    2000      3 Doors Down               Kryptonite  3:53    2
# 3    2000      3 Doors Down                    Loser  4:24    3
# 4    2000          504 Boyz            Wobble Wobble  3:35    4
# ..    ...               ...                      ...   ...  ...
# 312  2000       Yankee Grey     Another Nine Minutes  3:10  312
# 313  2000  Yearwood, Trisha          Real Live Woman  3:55  313
# 314  2000   Ying Yang Twins  Whistle While You Tw...  4:19  314
# 315  2000     Zombie Nation            Kernkraft 400  3:30  315
# 316  2000   matchbox twenty                     Bent  4:12  316
#
# [317 rows x 5 columns]

# %%
billboard_song_info.to_csv("billboard_songs.csv",index=False)

# %%
billboard_ratings= billboard_melt.merge(billboard_song_info,on=["year","artist","track","time"])

# %%
billboard_ratings.sample(10)
# Out:
#        year                 artist                    track  time  \
# 16362  2000                    Mya  Case Of The Ex (What...  3:50
# 22426  2000                Tuesday                   I Know  4:06
# 18683  2000  Red Hot Chili Peppers                Otherside  4:13
# 5644   2000        Destiny's Child  Independent Women Pa...  3:38
# 3223   2000          Braxton, Toni  Just Be A Man About ...  4:10
# 21018  2000                  Sting              Desert Rose  3:52
# 6106   2000      Dixie Chicks, The         Cold Day In July  5:12
# 19666  2000          Sheist, Shade         Where I Wanna Be  4:16
# 17165  2000              Nine Days                  If I Am  4:18
# 22160  2000                  Train            Meet Virginia  3:55
#
#       date.entered  week  ratings   id
# 16362   2000-08-19  wk23      4.0  215
# 22426   2000-12-30   wk7      NaN  295
# 18683   2000-02-12  wk64      NaN  245
# 5644    2000-09-23  wk21      3.0   74
# 3223    2000-07-29  wk32      NaN   42
# ...

# %%
billboard_ratings=billboard_ratings[["id","week","ratings","date.entered"]]

# %%
billboard_ratings.to_csv("billboard_ratings.csv", index=False)

# %%
billboard_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24092 entries, 0 to 24091
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            24092 non-null  int32
#  1   week          24092 non-null  object
#  2   ratings       5307 non-null   float64
#  3   date.entered  24092 non-null  object
# dtypes: float64(1), int32(1), object(2)
# memory usage: 847.0+ KB

# %%
billboard_song_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 317 entries, 0 to 316
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    317 non-null    int64
#  1   artist  317 non-null    object
#  2   track   317 non-null    object
#  3   time    317 non-null    object
#  4   id      317 non-null    int32
# dtypes: int32(1), int64(1), object(3)
# memory usage: 21.7+ KB

# %%
billboard_melt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24092 entries, 0 to 24091
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          24092 non-null  int64
#  1   artist        24092 non-null  object
#  2   track         24092 non-null  object
#  3   time          24092 non-null  object
#  4   date.entered  24092 non-null  object
#  5   week          24092 non-null  object
#  6   ratings       5307 non-null   float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 1.3+ MB
